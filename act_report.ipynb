# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# Distribution of Ratings:
#
# In my exploratory data analysis, we began by employing a histogram to vividly illustrate the distribution of ratings within the Twitter dog dataset. This visualization serves as a window into the collective sentiment and popularity encapsulated in the ratings assigned to each tweet.T
# he distribution is skewed to the right, which can indicate that there are fewer tweets with exceptionally low ratings and more tweets with higher ratings, providing more context about the distribution shape.
# ![Distribution%20of%20Ratings.png](attachment:Distribution%20of%20Ratings.png)
#
# Most Common Dog Breeds:
#
# This visualization provides insights into the popularity of specific breeds.
# Golden Retriever: 139 mentions
# Labrador Retriever: 95 mentions
# Pembroke: 88 mentions
# Chihuahua: 78 mentions
# Pug: 54 mentions
#
# A visualization was generated to identify the top 5 most common dog breeds, shedding light on the popularity of these breeds among Twitter users.
# ![Most%20common%20dog%20breeds.png](attachment:Most%20common%20dog%20breeds.png)
#
# Commonly Mentioned Dog Stages:
#
# In the pursuit of comprehending the dynamics of Twitter dog-related conversations, our exploratory data analysis incorporated a powerful visualization method to ascertain the prevalence of various dog stages within the dataset. This endeavor led us to a significant revelation regarding the favored dog stages among users.
#
# The results of our analysis depict the following distribution of dog stages based on their frequency of mention:
# Pupper: 224 mentions
# Doggo: 75 mentions
# Puppo: 24 mentions
# Uncertain: 12 mentions
# Floofer: 9 mentions
# This insightful visualization allows us to unequivocally discern the stage that commands the highest degree of popularity among Twitter users. By understanding the prominence of specific dog stages in online conversations, we gain a deeper comprehension of the preferences and trends within the Twitter dog-loving community. Such findings serve as a foundational cornerstone for future analyses and discussions related to canine enthusiasts on the platform.
#
# ![most%20common%20dog%20stages.png](attachment:most%20common%20dog%20stages.png)
#
# In conclusion, EDA is a fundamental step in uncovering valuable insights within the Twitter dog dataset, setting the stage for deeper analysis.
